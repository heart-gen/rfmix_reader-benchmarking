# %%
import numpy as np
import pandas as pd
import session_info
from pyhere import here
from pathlib import Path

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import statsmodels.api as sm

# %%
# Genotype reader
from localqtl import PgenReader

# %%
# RFMix-reader core functions
from rfmix_reader import (
    read_rfmix,
    interpolate_array
)

# %%
APP_LOCUS = {
    "gene": "APP",
    "chrom": 21,
    "start": 25_300_000,
    "end": 26_700_000,
    "build": "GRCh38"
}
#verify start/end of APP gene on chromosome 21
APP_LOCUS
# Out:
# {'gene': 'APP',
#  'chrom': 21,
#  'start': 25300000,
#  'end': 26700000,
#  'build': 'GRCh38'}
